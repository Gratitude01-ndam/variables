# %% [markdown]
# # Part  1

# %%
# 1) It is a  regression problem because the variable 'trip_duration' is continuous and can take any value within a range.
# 2) The second error is worse because the customer does not book the ride because he/she thinks it takes too long, so you end up losing the customer.
# 3) Weather, Topography of NYC, hour of the day

# %% [markdown]
# # Part 2

# %%
# 4) a) 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the data
data = pd.read_csv('/Users/Admin/Desktop/NYC.csv')
print(data.describe())
# Define NYC boundaries
lat = 40.7
long = -73.9
# Check for coordinates that fall out of NYC
out_of_nyc = data[(data['pickup_latitude'] > lat) | (data['pickup_longitude'] < long)]
print(out_of_nyc)
# b) We drop that row in the dataset

# %%
# 5) A histogram will better show this since we are dealing with the frequency distribution of only a single variable ie trip_duration

# %% [markdown]
# # Part 3

# %%
# 6) 
import pandas as pd
data = pd.read_csv('/Users/Admin/Desktop/NYC.csv')
# Convert the string to a datetime object
data['pickup_datetime'] = pd.to_datetime(data['date_string'])
# Extract hour of the day (0-23) and day of the week (Monday=0, Sunday= 6)
data['hour_of_day'] = dt['date_time'].dt.hour
data['day_of_week'] = dt['date_time'].dt.dayofweek
print(data)
# The hour of the day is more predictive of traffic than the date because there are standard hours within the day for specific activities eg end of work hours or when schools close

# %%
# 7) Since the Haversine formula is used to calculate the distance between two points on a spherical surface given their latitude and longitude, we need it to get the distance between the customer's location and their service point
# 8)
import pandas as pd
data = pd.read_csv('/Users/Admin/Desktop/NYC.csv')
# Define binary mapping
binary_map = {'Y' : 1, 'N' : 0}
# Apply to dataset
data['store_and_fwd_flag'] = data['store_and_fwd_flag'].map(binary_map)
print(data)
# 9) customer_id, pickup_longitude, pickup_latitude, pickup_datetime, trip_duration, distance_km, hour_of_day, day_of_week
